# %%
import pandas as pd

# %%
df=pd.read_csv("loan_data.xls")

# %%
#data view

# %%
df.head(20)
# Out:
#     person_age person_gender person_education  person_income  person_emp_exp  \
# 0         22.0        female           Master        71948.0               0
# 1         21.0        female      High School        12282.0               0
# 2         25.0        female      High School        12438.0               3
# 3         23.0        female         Bachelor        79753.0               0
# 4         24.0          male           Master        66135.0               1
# 5         21.0        female      High School        12951.0               0
# 6         26.0        female         Bachelor        93471.0               1
# 7         24.0        female      High School        95550.0               5
# 8         24.0        female        Associate       100684.0               3
# 9         21.0        female      High School        12739.0               0
# 10        22.0        female      High School       102985.0               0
# ...

# %%
#bottom data

# %%
df.tail(20)
# Out:
#        person_age person_gender person_education  person_income  \
# 44980        28.0          male        Associate        68381.0
# 44981        25.0        female      High School        91444.0
# 44982        26.0          male         Bachelor       130495.0
# 44983        30.0          male         Bachelor        59688.0
# 44984        24.0        female      High School        75941.0
# 44985        36.0        female        Associate        61015.0
# 44986        34.0          male         Bachelor        41876.0
# 44987        34.0          male           Master        69210.0
# 44988        28.0        female        Associate        49170.0
# 44989        24.0          male         Bachelor        16779.0
# 44990        31.0          male           Master       136832.0
# 44991        24.0          male      High School        37786.0
# 44992        23.0        female         Bachelor        40925.0
# 44993        27.0        female      High School        35512.0
# ...

# %%
#random sample
df.sample()
# Out:
#       person_age person_gender person_education  person_income  \
# 4646        24.0          male         Bachelor       286608.0
#
#       person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 4646               2                  RENT    10000.0     VENTURE
#
#       loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 4646          13.67                 0.03                         2.0
#
#       credit_score previous_loan_defaults_on_file  loan_status
# 4646           664                             No            1

# %%
df.sample(10)
# Out:
#        person_age person_gender person_education  person_income  \
# 9698         24.0        female           Master       121067.0
# 4046         23.0        female         Bachelor        74112.0
# 18926        30.0          male           Master        16425.0
# 30689        45.0          male        Associate        74221.0
# 28932        28.0          male         Bachelor        78935.0
# 27680        34.0        female        Associate       193124.0
# 34073        35.0          male           Master        49402.0
# 44304        36.0          male        Associate        59782.0
# 32097        43.0        female        Doctorate        55997.0
# 7268         26.0          male         Bachelor        39588.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 9698                4                  RENT     8400.0            MEDICAL
# 4046                3                  RENT     4000.0  DEBTCONSOLIDATION
# ...

# %%
df.dtypes
# Out:
# person_age                        float64
# person_gender                      object
# person_education                   object
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                         float64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['person_age']
# Out:
# 0        22.0
# 1        21.0
# 2        25.0
# 3        23.0
# 4        24.0
#          ...
# 44995    27.0
# 44996    37.0
# 44997    33.0
# 44998    29.0
# 44999    24.0
# Name: person_age, Length: 45000, dtype: float64

# %%
df['person_age'].max()
# Out:
# np.float64(144.0)

# %%
df['person_age'].min()
# Out:
# np.float64(20.0)

# %%
df.describe ()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
#check null
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
#check dublicate
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#count check
df['person_education'].value_counts()
# Out:
# person_education
# Bachelor       13399
# Associate      12028
# High School    11972
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
df['person_education'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate'],
#       dtype=object)

# %%
df['person_gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['person_home_ownership'].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)

# %%
df['Education'] =df['person_education'].replace({'Master': 0 , 'High School' : 1, 'Bachelor': 2, 'Associate': 3, 'Doctorate': 4 })
# Out:
# C:\Users\rojan\AppData\Local\Temp\ipykernel_3460\945449012.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Education'] =df['person_education'].replace({'Master': 0 , 'High School' : 1, 'Bachelor': 2, 'Associate': 3, 'Doctorate': 4 })

# %%
df.dtypes
# Out:
# person_age                        float64
# person_gender                      object
# person_education                   object
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                         float64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# Education                           int64
# dtype: object

# %%
df['person_age'].astype(int)
# Out:
# 0        22
# 1        21
# 2        25
# 3        23
# 4        24
#          ..
# 44995    27
# 44996    37
# 44997    33
# 44998    29
# 44999    24
# Name: person_age, Length: 45000, dtype: int64

# %%
df['person_age'] = df['person_age'].astype(int)

# %%
df.dtypes
# Out:
# person_age                          int64
# person_gender                      object
# person_education                   object
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                         float64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# Education                           int64
# dtype: object

# %%
df['loan_amnt'].mean()
# Out:
# np.float64(9583.157555555556)

# %%
df['loan_amnt'].astype(int)
# Out:
# 0        35000
# 1         1000
# 2         5500
# 3        35000
# 4        35000
#          ...
# 44995    15000
# 44996     9000
# 44997     2771
# 44998    12000
# 44999     6665
# Name: loan_amnt, Length: 45000, dtype: int64

# %%
# df['loan_amnt'] = df['loan_amnt'].astype(int)

# %%
df['loan_amnt']
# Out:
# 0        35000.0
# 1         1000.0
# 2         5500.0
# 3        35000.0
# 4        35000.0
#           ...
# 44995    15000.0
# 44996     9000.0
# 44997     2771.0
# 44998    12000.0
# 44999     6665.0
# Name: loan_amnt, Length: 45000, dtype: float64

# %%
df['person_age']
# Out:
# 0        22
# 1        21
# 2        25
# 3        23
# 4        24
#          ..
# 44995    27
# 44996    37
# 44997    33
# 44998    29
# 44999    24
# Name: person_age, Length: 45000, dtype: int64

# %%
df[(df['person_age']> 30) & (df['person_age']<60)]
# Out:
#        person_age person_gender person_education  person_income  \
# 17833          32        female      High School      1440746.0
# 17834          34          male         Bachelor      1138723.0
# 17836          33          male         Bachelor        93638.0
# 17840          35        female        Associate       778515.0
# 17842          31        female           Master        88456.0
# ...           ...           ...              ...            ...
# 44986          34          male         Bachelor        41876.0
# 44987          34          male           Master        69210.0
# 44990          31          male           Master       136832.0
# 44996          37        female        Associate        65800.0
# 44997          33          male        Associate        56942.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 17833               6              MORTGAGE    12000.0            VENTURE
# ...

# %%
df['person_age'].sort_values()
# Out:
# 1313      20
# 12943     20
# 17196     20
# 11889     20
# 11902     20
#         ...
# 747      123
# 575      123
# 183      144
# 32297    144
# 81       144
# Name: person_age, Length: 45000, dtype: int64

# %%
df['person_age'].sort_values(ascending=False)
# Out:
# 81       144
# 32297    144
# 183      144
# 575      123
# 747      123
#         ...
# 36423     20
# 5648      20
# 39292     20
# 9926      20
# 1313      20
# Name: person_age, Length: 45000, dtype: int64

# %%
#bivarite analaysis

# %%
df.groupby('person_gender')['loan_amnt'].sum()
# Out:
# person_gender
# female    191682371.0
# male      239559719.0
# Name: loan_amnt, dtype: float64

# %%
df.groupby('person_gender')['loan_amnt'].sum()
# Out:
# person_gender
# female    191682371.0
# male      239559719.0
# Name: loan_amnt, dtype: float64

# %%
df.groupby('person_gender')['loan_amnt'].sum().mean()
# Out:
# np.float64(215621045.0)

# %%
df.groupby('person_education')['person_income'].sum()
# Out:
# person_education
# Associate      9.699574e+08
# Bachelor       1.067945e+09
# Doctorate      5.417265e+07
# High School    9.604489e+08
# Master         5.618336e+08
# Name: person_income, dtype: float64

# %%
df.groupby('person_education')['person_income'].mean()
# Out:
# person_education
# Associate      80641.623628
# Bachelor       79703.319725
# Doctorate      87234.541063
# High School    80224.597645
# Master         80491.924355
# Name: person_income, dtype: float64

# %%
df.groupby('person_education')['person_income'].sum().mean()
# Out:
# np.float64(722871479.0)

# %%
df.groupby('person_education')['person_income'].sum().mean()
# Out:
# np.float64(722871479.0)

# %%
df['sort_imcome'] = df.groupby('person_education')['person_income'].mean()

# %%
df['sort_imcome'].sort_values()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 44995   NaN
# 44996   NaN
# 44997   NaN
# 44998   NaN
# 44999   NaN
# Name: sort_imcome, Length: 45000, dtype: float64

# %%
df['sort_imcome']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 44995   NaN
# 44996   NaN
# 44997   NaN
# 44998   NaN
# 44999   NaN
# Name: sort_imcome, Length: 45000, dtype: float64

# %%
#fuction

# %%
def fun_ction(a,b,c):
    result = a+b+c
    print(result)
    return result

# %%
fun_ction(20,456,78)
# Out:
# 554
# 554

# %%
df['person_gender'] =df['person_gender'].replace({ 'male' : 1, 'female': 2,  })
# Out:
# C:\Users\rojan\AppData\Local\Temp\ipykernel_3460\64674652.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_gender'] =df['person_gender'].replace({ 'male' : 1, 'female': 2,  })

# %%
df['person_home_ownership'] =df['person_home_ownership'].replace({'RENT' : 1, 'MORTGAGE': 2, 'OTHER': 3, 'OWN': 4,})
# Out:
# C:\Users\rojan\AppData\Local\Temp\ipykernel_3460\4155277010.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_home_ownership'] =df['person_home_ownership'].replace({'RENT' : 1, 'MORTGAGE': 2, 'OTHER': 3, 'OWN': 4,})

# %%
df['person_home_ownership'].unique()
# Out:
# array([1, 4, 2, 3])

# %%
df['loan_intent'].unique()
# Out:
# array(['PERSONAL', 'EDUCATION', 'MEDICAL', 'VENTURE', 'HOMEIMPROVEMENT',
#        'DEBTCONSOLIDATION'], dtype=object)

# %%
df['loan_intent'] =df['loan_intent'].replace({'PERSONAL' : 1, 'EDUCATION': 2, 'MEDICAL': 3, 'VENTURE': 4, 'HOMEIMPROVEMENT':5, 'DEBTCONSOLIDATION':6})
# Out:
# C:\Users\rojan\AppData\Local\Temp\ipykernel_3460\1354491090.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['loan_intent'] =df['loan_intent'].replace({'PERSONAL' : 1, 'EDUCATION': 2, 'MEDICAL': 3, 'VENTURE': 4, 'HOMEIMPROVEMENT':5, 'DEBTCONSOLIDATION':6})

# %%
df['loan_intent'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
df['previous_loan_defaults_on_file'] =df['previous_loan_defaults_on_file'].replace({ 'Yes' : 1, 'No': 2, })
# Out:
# C:\Users\rojan\AppData\Local\Temp\ipykernel_3460\3933195391.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['previous_loan_defaults_on_file'] =df['previous_loan_defaults_on_file'].replace({ 'Yes' : 1, 'No': 2, })

# %%
df['previous_loan_defaults_on_file'].unique()
# Out:
# array([2, 1])

# %%
df['sort_imcome'].unique()
# Out:
# array([nan])

# %%
df['person_education'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate'],
#       dtype=object)

# %%
df['person_education'] =df['person_education'].replace({ 'Master' : 0, 'High School': 1,'Bachelor':2,'Associate':3,'Doctorate':4 })
# Out:
# C:\Users\rojan\AppData\Local\Temp\ipykernel_3460\3553536196.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_education'] =df['person_education'].replace({ 'Master' : 0, 'High School': 1,'Bachelor':2,'Associate':3,'Doctorate':4 })

# %%
df['person_education'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df = df.drop('sort_imcome', axis=1)

# %%
#seprate data into ndependent ad dependent variables
#column drop

# %%
#x=df.drop("drop_column_name', axis=1 1 for verticle 0 for hrizental)
#x=df.drop("['drop_column_name','drop_column_name', axis=1] 1 for verticle 0 for hrizental)

# %%
x= df.drop(['loan_amnt','Education'], axis =1)
y= df['loan_amnt']

# %%
x.shape #shows rows and column
# Out:
# (45000, 13)

# %%
x.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
x.dtypes
# Out:
# person_age                          int64
# person_gender                       int64
# person_education                    int64
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership               int64
# loan_intent                         int64
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file      int64
# loan_status                         int64
# dtype: object

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(x,y,test_size=0.2, random_state = 42)

# %%
X_train
# Out:
#        person_age  person_gender  person_education  person_income  \
# 25180          34              2                 2        97265.0
# 12555          25              1                 1        72953.0
# 29153          41              2                 0       322597.0
# 23838          27              1                 3        94232.0
# 35686          27              1                 0        84873.0
# ...           ...            ...               ...            ...
# 11284          26              1                 1        88451.0
# 44732          25              2                 1        34772.0
# 38158          33              2                 3        58317.0
# 860            26              1                 0       178602.0
# 15795          26              2                 1       210894.0
#
#        person_emp_exp  person_home_ownership  loan_intent  loan_int_rate  \
# 25180              11                      2            1          12.73
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
 lr_model=LinearRegression()

# %%
#Train The Model

# %%
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#predict the model
predict =lr_model.predict(X_test)

# %%
predict
# Out:
# array([ 6429.67364164, 10025.50217732,  6889.95724772, ...,
#        11925.26561526, 13084.50554747, 13921.69877691], shape=(9000,))

# %%
y_test
# Out:
# 37979     7500.0
# 9911      9000.0
# 43386     5000.0
# 13822     5000.0
# 44810    10000.0
#           ...
# 14572    14000.0
# 30384     6725.0
# 36665    14000.0
# 30569     8000.0
# 5321      8500.0
# Name: loan_amnt, Length: 9000, dtype: float64

# %%
result =pd.DataFrame({'Actual_value':y_test,'predtected_by_model':predict})

result
# Out:
#        Actual_value  predtected_by_model
# 37979        7500.0          6429.673642
# 9911         9000.0         10025.502177
# 43386        5000.0          6889.957248
# 13822        5000.0          9923.601822
# 44810       10000.0          8991.392624
# ...             ...                  ...
# 14572       14000.0          9902.537725
# 30384        6725.0          8825.406705
# 36665       14000.0         11925.265615
# 30569        8000.0         13084.505547
# 5321         8500.0         13921.698777
#
# [9000 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
r2_score=r2_score(y_test,predict)
r2_score
#model accuracy

# %%
mse = mean_squared_error(y_test, predict)
mse

# %%
mae = mean_absolute_error(y_test, predict)
mae

# %%
result.to_csv('result.csv', index=False)
